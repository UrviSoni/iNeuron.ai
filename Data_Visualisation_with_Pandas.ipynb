# %% [markdown]
# <a href="https://colab.research.google.com/github/UrviSoni/iNeuron.ai/blob/master/Data_Visualisation_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from numpy.random import randn, randint, uniform, sample

# %%
randn(1000)
# Out:
# array([-7.15431014e-01, -3.24398039e-01,  2.70079087e-01, -4.64137222e-01,
#         1.46744441e-01,  1.61535170e+00, -2.98824468e-02, -1.62305586e+00,
#        -1.56804978e-01,  5.62120992e-01, -1.02073304e+00,  9.20257222e-01,
#        -4.88085094e-01,  6.51802805e-01,  3.68010340e-01,  8.65590632e-01,
#         1.08132743e+00, -1.69691736e+00, -1.28460225e+00,  1.05418078e+00,
#         1.20030002e+00,  7.98536030e-01, -7.14029336e-01,  9.64130096e-01,
#        -5.12160678e-01,  1.18312814e+00,  6.96433640e-01,  5.74971153e-01,
#         9.29931566e-01, -8.83938347e-01, -9.07056262e-01,  6.49662697e-02,
#        -1.29762099e+00,  3.59316654e-01, -1.27328120e+00, -2.85719109e-01,
#         6.74369722e-01, -1.44565035e+00, -1.88730919e-01, -1.24912471e+00,
#        -3.97853869e-01,  1.14254007e+00, -3.19918656e-01, -2.48353072e-01,
#        -1.03863801e+00,  7.44336192e-01,  8.94223652e-01, -7.57250066e-01,
# ...

# %%
df = pd.DataFrame(randn(1000))
df
# Out:
#             0
# 0   -1.326689
# 1    1.253628
# 2   -1.047666
# 3   -1.103681
# 4   -1.104677
# ..        ...
# 995 -0.348936
# 996  0.745556
# 997 -1.894607
# 998 -0.942572
# 999 -0.455054
#
# [1000 rows x 1 columns]

# %%
pd.date_range('2019-06-07', periods = 1000)
# Out:
# DatetimeIndex(['2019-06-07', '2019-06-08', '2019-06-09', '2019-06-10',
#                '2019-06-11', '2019-06-12', '2019-06-13', '2019-06-14',
#                '2019-06-15', '2019-06-16',
#                ...
#                '2022-02-21', '2022-02-22', '2022-02-23', '2022-02-24',
#                '2022-02-25', '2022-02-26', '2022-02-27', '2022-02-28',
#                '2022-03-01', '2022-03-02'],
#               dtype='datetime64[ns]', length=1000, freq='D')

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])

# %%
df
# Out:
#                value
# 2019-06-07 -1.231629
# 2019-06-08 -0.490478
# 2019-06-09  0.232852
# 2019-06-10 -0.295098
# 2019-06-11  0.337939
# ...              ...
# 2022-02-26  0.344626
# 2022-02-27 -1.515352
# 2022-02-28 -0.805237
# 2022-03-01 -1.182160
# 2022-03-02 -0.043908
#
# [1000 rows x 1 columns]

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07 -1.646339
# 2019-06-08  0.119722
# 2019-06-09 -0.345182
# 2019-06-10 -1.617565
# 2019-06-11 -0.130855

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07 -1.646339
# 2019-06-08 -1.526617
# 2019-06-09 -1.871799
# 2019-06-10 -3.489364
# 2019-06-11 -3.620220

# %%
df.plot()

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07    0.609557
# 2019-06-08   -0.911425
# 2019-06-09   -0.979468
# 2019-06-10   -1.063286
# 2019-06-11   -0.794169
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(5,5))

# %%
ts.plot(figsize=(50,50))

# %%
plt.plot(ts)

# %%
df.plot()

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.plot()

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts
# Out:
# 2019-06-07     0.609557
# 2019-06-08    -0.911425
# 2019-06-09    -0.979468
# 2019-06-10    -1.063286
# 2019-06-11    -0.794169
#                 ...
# 2022-02-26    23.967377
# 2022-02-27    24.062014
# 2022-02-28    24.010167
# 2022-03-01    24.430967
# 2022-03-02    24.950142
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()

# %%
ts.plot(kind = 'bar', figsize=(200,80))

# %%
ts.plot(kind = 'barh', figsize=(200,80))

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = iris.drop(['species'], axis = 1)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot(kind='barh')

# %%
df.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
titanic['pclass'].plot()

# %%
titanic['pclass'].plot(kind = 'bar')

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -0.945012  0.124820 -0.509633  0.133034
# 1 -0.471845 -0.252116 -2.544475 -1.105300
# 2 -1.322954 -0.396210  1.896088  1.147076
# 3 -1.956102 -0.426830 -0.816640  0.800750
# 4 -1.164196 -0.360842 -0.515607  0.820993
# 5 -1.023182 -0.960398  0.821824  0.169981
# 6 -0.508439 -1.474178  1.837716  0.043100
# 7  0.637644 -0.596257  1.755130 -0.481208
# 8  1.111243  0.563069  0.292378  1.720779
# 9  0.353696 -1.472340 -1.994795 -0.039614

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
df.plot.barh()

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
iris['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
iris['sepal_length'].plot.hist()

# %%
iris.plot.hist()

# %%
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = False, bins = 100)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 100)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'b', alpha = 0.1, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0ee288b2b0>,
# ...
#       dtype=object)

# %%
df.diff().hist(color = 'r', alpha = 0.9, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0ee2248358>,
# ...
#       dtype=object)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50)

# %%
iris.plot(color = 'r', alpha = 0.9, figsize=(10,10))

# %%
df.diff().hist(color = '#FFFF00', alpha = 0.9, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0ee1d84da0>,
# ...
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
#df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', color = 'r')

# %%
df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', color = 'g')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 50)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 10, C = 'sepal_width')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0ee1197b38>,
# ...
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0ee106c6a0>,
# ...
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), color = 'r')
plt.show()

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0edff2aa20>,
# ...
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()

# %%
from descartes import PolygonPatch

# %%
pip install git+git://github.com/geopandas/geopandas.git
# Out:
# ...
#   Cloning git://github.com/geopandas/geopandas.git to /tmp/pip-req-build-f8esg811
#   Running command git clone -q git://github.com/geopandas/geopandas.git /tmp/pip-req-build-f8esg811
# ...
#      |████████████████████████████████| 14.8MB 303kB/s
# ...
#      |████████████████████████████████| 10.9MB 41.2MB/s
# ...
#   Created wheel for geopandas: filename=geopandas-0.8.0+45.g63615be-py2.py3-none-any.whl size=963934 sha256=7ef90cb40a0216767dc9beeb54328ced6d3e3468bdaf97cba8b00e5adda5880f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v20im12v/wheels/91/24/71/376c9c67192694168352afcccc2d264248f7e2cc6192997186
# Successfully built geopandas
# ...

# %%
import geopandas as gpd

# %%
map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
map_df.plot()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: London_Borough_Excluding_MHW.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-118-335b3608a8ad> in <module>()
# ----> 1 map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
#       2 # check data type so we can see that this is not a normal dataframe, but a GEOdataframe
#       3 map_df.head()
#       4 map_df.plot()
#
# /usr/local/lib/python3.6/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     123
#     124     with fiona_env():
# --> 125         with reader(path_or_bytes, **kwargs) as features:
#     126
# ...

# %%
map_df
# Out:
#                       NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER  \
# 0     Kingston upon Thames  E09000021   3726.117       0.000         F
# 1                  Croydon  E09000008   8649.441       0.000         F
# 2                  Bromley  E09000006  15013.487       0.000         F
# 3                 Hounslow  E09000018   5658.541      60.755         F
# 4                   Ealing  E09000009   5554.428       0.000         F
# 5                 Havering  E09000016  11445.735     210.763         F
# 6               Hillingdon  E09000017  11570.063       0.000         F
# 7                   Harrow  E09000015   5046.330       0.000         F
# 8                    Brent  E09000005   4323.270       0.000         F
# 9                   Barnet  E09000003   8674.837       0.000         F
# 10                 Lambeth  E09000022   2724.940      43.927         T
# 11               Southwark  E09000028   2991.340     105.139         T
# ...
